# %% [markdown]
# [9- How to implement a (simple) neural network with TensorFlow 2](https://www.youtube.com/watch?v=JdXxaZcQer8)

# %% [markdown]
# Building a Neural network with the tensorflow library

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
import numpy as np
from random import random

# %%
def generate_dataset(num_samples, test_size=0.33):
    """Generates train/test data for sum operation
    :param num_samples (int): Num of total samples in dataset
    :param test_size (int): Ratio of num_samples used as test set
    :return x_train (ndarray): 2d array with input data for training
    :return x_test (ndarray): 2d array with input data for testing
    :return y_train (ndarray): 2d array with target data for training
    :return y_test (ndarray): 2d array with target data for testing
    """

    # build inputs/targets for sum operation: y[0][0] = x[0][0] + x[0][1]
    x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
    y = np.array([[i[0] + i[1]] for i in x])

    # split dataset into test and training sets
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
    return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":

    # create a dataset with 2000 samples
    x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)

    # build model with 3 layers: 2 -> 5 -> 1
    model = tf.keras.models.Sequential([
      # the input -> hidden layer
      tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
      # the hidden -> output layer
      tf.keras.layers.Dense(1, activation="sigmoid")
    ])

    # choose optimiser
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)

    # compile model
    model.compile(optimizer=optimizer, loss='mse')

    # train model
    model.fit(x_train, y_train, epochs=100)

    # evaluate model on test set
    print("\nEvaluation on the test set:")
    model.evaluate(x_test,  y_test, verbose=2)

    # get predictions
    data = np.array([[0.1, 0.2], [0.2, 0.2]])
    predictions = model.predict(data)

    # print predictions
    print("\nPredictions:")
    for d, p in zip(data, predictions):
        print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# 110/110 [==============================] - 3s 9ms/step - loss: 0.0517
# Epoch 2/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0443
# Epoch 3/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0441
# Epoch 4/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0439
# Epoch 5/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0436
# Epoch 6/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0434
# Epoch 7/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0432
# Epoch 8/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0430
# Epoch 9/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0428
# Epoch 10/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0426
# Epoch 11/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0425
# Epoch 12/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0423
# Epoch 13/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0421
# Epoch 14/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0419
# Epoch 15/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0418
# Epoch 16/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.0416
# Epoch 17/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0414
# Epoch 18/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0413
# Epoch 19/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0411
# Epoch 20/100
# 110/110 [==============================] - 1s 8ms/step - loss: 0.0410
# Epoch 21/100
# 110/110 [==============================] - 1s 6ms/step - loss: 0.0408
# Epoch 22/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0406
# Epoch 23/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0404
# Epoch 24/100
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0403
# Epoch 25/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0401
# Epoch 26/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0399
# Epoch 27/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0397
# Epoch 28/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0395
# Epoch 29/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0393
# Epoch 30/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0391
# Epoch 31/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0389
# Epoch 32/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0386
# Epoch 33/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0384
# Epoch 34/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0382
# Epoch 35/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 36/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0376
# Epoch 37/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0373
# Epoch 38/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0370
# Epoch 39/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 40/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0364
# Epoch 41/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0361
# Epoch 42/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0357
# Epoch 43/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0353
# Epoch 44/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0349
# Epoch 45/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0345
# Epoch 46/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0341
# Epoch 47/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0336
# Epoch 48/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0331
# Epoch 49/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0326
# Epoch 50/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 51/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 52/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0310
# Epoch 53/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0305
# Epoch 54/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0299
# Epoch 55/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 56/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 57/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 58/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 59/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 60/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0259
# Epoch 61/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 62/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0245
# Epoch 63/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 64/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0229
# Epoch 65/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0222
# Epoch 66/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0214
# Epoch 67/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 68/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0199
# Epoch 69/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 70/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 71/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0175
# Epoch 72/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0168
# Epoch 73/100
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 74/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 75/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0146
# Epoch 76/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 77/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0132
# Epoch 78/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 79/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 80/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0112
# Epoch 81/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0106
# Epoch 82/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 83/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 84/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0089
# Epoch 85/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 86/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 87/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 88/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 89/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 90/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 91/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 92/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 93/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 94/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 95/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 96/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 97/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 98/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 99/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 100/100
# 110/110 [==============================] - 0s 2ms/step - loss: 0.0032
#
# Evaluation on the test set:
# 47/47 - 0s - loss: 0.0031 - 239ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 106ms/step
#
# Predictions:
# 0.1 + 0.2 = 0.3476579487323761
# 0.2 + 0.2 = 0.42234477400779724
